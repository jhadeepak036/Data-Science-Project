# %% [markdown]
# # **IRIS_DATASET_ADVANCE_VISUALIZATION_EDA**

# %% [markdown]
# ![Iris](https://www.integratedots.com/wp-content/uploads/2019/06/iris_petal-sepal-e1560211020463.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
Iris = pd.read_csv(r'/kaggle/input/iris-dataset/Iris.csv')

# %%
Iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
Iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
Iris.drop('Id',axis=1,inplace=True)

# %%
Iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
Iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
Iris['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# **Bar Plot**

# %% [markdown]
# This data set has three varities of Iris plant.

# %%
sns.countplot(x='Species', data=Iris)
plt.show()

# %% [markdown]
# We can see that there are 50 samples each of all the Iris Species in the data set.

# %% [markdown]
# Jointplot is seaborn library specific and can be used to quickly visualize and analyze the relationship between two variables and describe their individual distributions on the same plot.

# %%
Iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
Sepal_Fig=sns.jointplot(x='SepalLengthCm',y='SepalWidthCm',data=Iris)

# %%
Sepal_Fig=sns.jointplot(x='SepalLengthCm',y='SepalWidthCm',data=Iris, kind='reg')

# %%
Sepal_Fig=sns.jointplot(x='SepalLengthCm',y='SepalWidthCm',data=Iris, kind='hex')

# %% [markdown]
# **FacetGrid Plot**

# %%
sns.FacetGrid(Iris,hue='Species')\
.map(plt.scatter,'SepalLengthCm','SepalWidthCm')\
.add_legend()

# %% [markdown]
# **Box plot or Whisker plot**

# %%
Iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
Petal_Fig = sns.boxplot(data=Iris,x='Species',y='PetalLengthCm',linewidth=2.5,orient='v',dodge=False)

# %%
Iris.boxplot(by='Species', figsize=(12,6))
# Out:
# array([[<AxesSubplot:title={'center':'PetalLengthCm'}, xlabel='[Species]'>,
#         <AxesSubplot:title={'center':'PetalWidthCm'}, xlabel='[Species]'>],
#        [<AxesSubplot:title={'center':'SepalLengthCm'}, xlabel='[Species]'>,
#         <AxesSubplot:title={'center':'SepalWidthCm'}, xlabel='[Species]'>]],
#       dtype=object)

# %%
Sepal_Fig=plt.gcf()
Sepal_Fig.set_size_inches(10,7)
Sepal_fig=sns.stripplot(x='Species',y='SepalLengthCm',data=Iris,jitter=True,edgecolor='gray',size=8,palette='winter',orient='v')

# %%
Sepal_Fig=plt.gcf()
Sepal_Fig.set_size_inches(10,7)
Sepal_Fig=sns.boxplot(x='Species',y='SepalLengthCm',data=Iris)
Sepal_Fig=sns.stripplot(x='Species',y='SepalLengthCm',data=Iris,jitter=True,edgecolor='yellow')

# %%
Petal_Fig=sns.boxplot(x='Species',y='PetalLengthCm',data=Iris)
Petal_Fig=sns.stripplot(x='Species',y='PetalLengthCm',data=Iris,jitter=True,edgecolor='gray')

# %% [markdown]
# **Violin Plot**

# %%
Sepal_Fig=plt.gcf()
Sepal_Fig.set_size_inches(10,7)
Sepal_Fig=sns.violinplot(data=Iris,x='Species',y='SepalLengthCm')

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.violinplot(x='Species',y='PetalLengthCm',data=Iris)
plt.subplot(2,2,2)
sns.violinplot(x='Species',y='PetalWidthCm',data=Iris)
plt.subplot(2,2,3)
sns.violinplot(x='Species',y='SepalLengthCm',data=Iris)
plt.subplot(2,2,4)
sns.violinplot(x='Species',y='SepalWidthCm',data=Iris)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='SepalWidthCm'>

# %% [markdown]
# **Pair Plot**

# %%
sns.pairplot(data=Iris, kind='scatter')

# %%
sns.pairplot(data=Iris,hue='Species')

# %% [markdown]
# **Heat map**

# %%
Fig=plt.gcf()
Fig.set_size_inches(10,7)
Fig=sns.heatmap(Iris.corr(),annot=True,cmap='cubehelix',linewidths=1,linecolor='k',square=True,mask=False,vmin=-1,vmax=1,cbar_kws={'orientation':'vertical'},cbar=True)

# %% [markdown]
# **Distribution plot**

# %%
Fig=plt.gcf()
Fig.set_size_inches(12,6)
Iris.hist(edgecolor='black',linewidth=1.2)
# Out:
# array([[<AxesSubplot:title={'center':'SepalLengthCm'}>,
#         <AxesSubplot:title={'center':'SepalWidthCm'}>],
#        [<AxesSubplot:title={'center':'PetalLengthCm'}>,
#         <AxesSubplot:title={'center':'PetalWidthCm'}>]], dtype=object)

# %% [markdown]
# **Swarm plot**

# %%
Fig=plt.gcf()
Fig.set_size_inches(10,7)
sns.set(style='darkgrid')
petal_Fig=sns.swarmplot(data=Iris,x='Species',y='PetalLengthCm')

# %%
sns.set(style="whitegrid")
Fig=plt.gcf()
Fig.set_size_inches(10,7)
Petal_Fig = sns.violinplot(x="Species", y="PetalLengthCm", data=Iris, inner=None)
Petal_Fig = sns.swarmplot(x="Species", y="PetalLengthCm", data=Iris,color="white", edgecolor="black")

# %% [markdown]
# **LM PLot**

# %%
Petal_Fig=sns.lmplot(x="PetalLengthCm", y="PetalWidthCm",data=Iris)

# %% [markdown]
# **Facet Grid**

# %%
sns.FacetGrid(data=Iris, hue="Species")\
.map(sns.kdeplot, "PetalLengthCm")\
.add_legend()
plt.ioff()

# %% [markdown]
# **Cat Plot**

# %%
sns.catplot(data=Iris,x='Species',y='SepalLengthCm',kind='point')
plt.ioff()
plt.show()

# %% [markdown]
# **Boxen Plot**

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.boxenplot(data=Iris,x='Species',y='SepalLengthCm')
plt.show()

# %% [markdown]
# **KDE Plot**

# %%
sub=Iris[Iris['Species']=='Iris-setosa']
sns.kdeplot(data=sub[['SepalLengthCm','SepalWidthCm']],cbar="plasma",shade=True, shade_lowest=False)
plt.title('Iris-setosa')
plt.xlabel('Sepal Length Cm')
plt.ylabel('Sepal Width Cm')
plt.show()

# %% [markdown]
# **Dashboard**

# %%
sns.set_style('darkgrid')
f,axes=plt.subplots(2,2,figsize=(15,15))
k1=sns.boxplot(x='Species',y='PetalLengthCm',data=Iris,ax=axes[0,0])
k2=sns.violinplot(x='Species',y='SepalLengthCm',data=Iris,ax=axes[0,1])
k3=sns.stripplot(x='Species',y='SepalLengthCm',data=Iris,jitter=True,edgecolor='gray',size=8,palette='winter',orient='v',ax=axes[1,0])
axes[1,1].hist(Iris.PetalLengthCm,bins=100)
plt.show()

# %% [markdown]
# **Stacked Histogram**

# %%
Iris['Species']=Iris['Species'].astype('category')
Iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
list1=list()
mylabels=list()
for gen in Iris.Species.cat.categories:
    list1.append(Iris[Iris.Species==gen].SepalLengthCm)
    mylabels.append(gen)
h=plt.hist(list1,bins=30,stacked=True,rwidth=1,label=mylabels)
plt.legend()
plt.show()

# %% [markdown]
# **Area Plot**

# %%
Iris.plot.area(y=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'],alpha=0.4,figsize=(12,6));
plt.show()

# %% [markdown]
# **Dist plot**

# %%
sns.distplot(Iris['SepalLengthCm'],kde=True,bins=20);
plt.show()
